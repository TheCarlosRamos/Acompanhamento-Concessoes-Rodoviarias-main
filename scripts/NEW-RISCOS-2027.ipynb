# %%
from openpyxl import load_workbook
import pandas as pd
from collections import defaultdict

# %%
def expandir_mescladas(ws):
    """
    Copia o valor da célula superior esquerda para todas as células
    pertencentes à região mesclada.
    """
    for merged in list(ws.merged_cells.ranges):

        valor = ws.cell(
            merged.min_row,
            merged.min_col
        ).value

        min_row = merged.min_row
        max_row = merged.max_row
        min_col = merged.min_col
        max_col = merged.max_col

        ws.unmerge_cells(str(merged))

        for r in range(min_row, max_row + 1):
            for c in range(min_col, max_col + 1):
                ws.cell(r, c).value = valor

# %%
def montar_cabecalho(ws):
    """
    Monta automaticamente o cabeçalho da planilha PPI.

    Expande células mescladas e propaga os títulos horizontal e
    verticalmente antes de concatenar os níveis do cabeçalho.
    """

    # Expande as células mescladas
    expandir_mescladas(ws)

    # Linhas do cabeçalho (Excel)
    HEADER_ROWS = [2, 3, 4, 5, 6, 7]

    # ------------------------------------------------------------------
    # Cria uma matriz contendo somente o cabeçalho
    # ------------------------------------------------------------------

    cab = []

    for r in HEADER_ROWS:

        linha = []

        for c in range(1, ws.max_column + 1):

            linha.append(ws.cell(r, c).value)

        cab.append(linha)

    cab = pd.DataFrame(cab)

    # ------------------------------------------------------------------
    # Propaga valores das células mescladas
    # ------------------------------------------------------------------

    # esquerda -> direita
    cab = cab.ffill(axis=1)

    # cima -> baixo
    cab = cab.ffill(axis=0)

    # ------------------------------------------------------------------
    # Limpa valores inúteis
    # ------------------------------------------------------------------

    lixo = {
        "#REF!",
        "TOTAL",
        "SOMA",
        0,
        "0",
        None,
        ""
    }

    cab = cab.replace(list(lixo), pd.NA)

    # ------------------------------------------------------------------
    # Monta o nome de cada coluna
    # ------------------------------------------------------------------

    colunas = []

    for c in range(cab.shape[1]):

        partes = []

        for r in range(cab.shape[0]):

            valor = cab.iat[r, c]

            if pd.isna(valor):
                continue

            valor = str(valor).strip()

            if valor == "":
                continue

            # Ignora fórmulas
            if valor.startswith("="):
                continue

            # Ignora erros do Excel
            if valor.startswith("#"):
                continue

            # Ignora TOTAL e SOMA
            if valor.upper() in ("TOTAL", "SOMA"):
                continue

            # Ignora números puros
            try:
                float(valor.replace(",", "."))
                continue
            except:
                pass

            # =============================================================
            # ✅ CORREÇÃO: aqui é onde o valor válido é adicionado à lista
            # =============================================================
            partes.append(valor)

        colunas.append(" - ".join(partes))

    # ------------------------------------------------------------------
    # Remove duplicados
    # ------------------------------------------------------------------

    contador = defaultdict(int)

    novas = []

    for nome in colunas:

        contador[nome] += 1

        if contador[nome] == 1:

            novas.append(nome)

        else:

            novas.append(f"{nome}__{contador[nome]}")

    return novas

# %%
ARQUIVO = "Planilha de Monitoramento_PPI_2025_31_03_25_PPI_R21 - 2027.xlsx"

wb = load_workbook(
    ARQUIVO,
    data_only=False
)

ws = wb["META(2027)"]

colunas = montar_cabecalho(ws)
# Out:
# c:\Users\carlos.ramos\OneDrive - Presidência da República\Área de Trabalho\Planilhas\.venv\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
dados = list(ws.values)

df = pd.DataFrame(
    dados[7:],   # linha 8 do Excel = índice 7
    columns=colunas
)

# %%
for i, c in enumerate(colunas):

    if "PAVIMENTAÇÃO" in c.upper():
        print(i, c)
# Out:
# 9 DADOS CONTRATUAIS - PAVIMENTAÇÃO - Até 2022 - FÍSICO (km) - km (i) - EPL
# 10 DADOS CONTRATUAIS - PAVIMENTAÇÃO - Até 2022 - FÍSICO (km) - km (f) - EPL
# 11 DADOS CONTRATUAIS - PAVIMENTAÇÃO - Até 2022 - FÍSICO (km) - Ext. (km) - EPL
# 12 DADOS CONTRATUAIS - PAVIMENTAÇÃO - Até 2022 - PERCENTUAL (%) - Ext. (km) - EPL
# 13 DADOS CONTRATUAIS - PAVIMENTAÇÃO - Até 2022 - FINANCEIRO (R$) - Ext. (km) - EPL
# 14 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - km (i) - EPL
# 15 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - km (f) - EPL
# 16 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - Ext. (km) - EPL
# 17 DADOS CONTRATUAIS - PAVIMENTAÇÃO - PERCENTUAL (%) - Ext. (km) - EPL
# 18 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FINANCEIRO (R$) - Ext. (km) - EPL
# 19 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - km (i) - EPL__2
# 20 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - km (f) - EPL__2
# 21 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - Ext. (km) - EPL__2
# 22 DADOS CONTRATUAIS - PAVIMENTAÇÃO - PERCENTUAL (%) - Ext. (km) - EPL__2
# 23 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FINANCEIRO (R$) - Ext. (km) - EPL__2
# 24 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - km (i) - EPL__3
# 25 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - km (f) - EPL__3
# 26 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - Ext. (km) - EPL__3
# 27 DADOS CONTRATUAIS - PAVIMENTAÇÃO - PERCENTUAL (%) - Ext. (km) - EPL__3
# 28 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FINANCEIRO (R$) - Ext. (km) - EPL__3
# 29 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - km (i) - EPL__4
# 30 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - km (f) - EPL__4
# 31 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FÍSICO (km) - Ext. (km) - EPL__4
# 32 DADOS CONTRATUAIS - PAVIMENTAÇÃO - PERCENTUAL (%) - Ext. (km) - EPL__4
# 33 DADOS CONTRATUAIS - PAVIMENTAÇÃO - FINANCEIRO (R$) - Ext. (km) - EPL__4
# 34 DADOS CONTRATUAIS - PAVIMENTAÇÃO - PÓS 2026 - FÍSICO (km) - km (i) - EPL
# 35 DADOS CONTRATUAIS - PAVIMENTAÇÃO - PÓS 2026 - FÍSICO (km) - km (f) - EPL
# 36 DADOS CONTRATUAIS - PAVIMENTAÇÃO - PÓS 2026 - FÍSICO (km) - Ext. (km) - EPL
# 37 DADOS CONTRATUAIS - PAVIMENTAÇÃO - PÓS 2026 - PERCENTUAL (%) - Ext. (km) - EPL
# 38 DADOS CONTRATUAIS - PAVIMENTAÇÃO - PÓS 2026 - FINANCEIRO (R$) - Ext. (km) - EPL
# 177 METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - FÍSICO (km) - Descrição - Ext. (km) - EPL
# 178 METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - FÍSICO (km) - km (i) - Ext. (km) - EPL
# 179 METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - FÍSICO (km) - km (f) - Ext. (km) - EPL
# 180 METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - FÍSICO (km) - Ext. (km) - Ext. (km) - EPL
# 181 METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - PERCENTUAL (%) PLAN - PAV. TOTAL PLAN - Ext. (km)
# 182 METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - (km)% PLAN - Ext. (km)
# 183 METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - FINANCEIRO PLAN (R$) - Ext. (km)
# 184 METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - PERCENTUAL (%) EXEC - PAV. TOTAL EXEC - Ext. (km)
# 185 METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - (km)% EXEC - Ext. (km)
# 186 METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - FINANCEIRO (R$) - Ext. (km)
# 187 METAS ANO PRESENTE - RISCOS (Pavimentação) - SITUAÇÃO - (células contêm listas suspensas) - (células contêm listas suspensas)
# 188 METAS ANO PRESENTE - RISCOS (Pavimentação) - INTERFERÊNCIA - (células contêm listas suspensas) - (células contêm listas suspensas)
# 189 METAS ANO PRESENTE - RISCOS (Pavimentação) - PRINCIPAL - (células contêm listas suspensas) - (células contêm listas suspensas)
# 190 METAS ANO PRESENTE - RISCOS (Pavimentação) - NÍVEL DE ALERTA - (células contêm listas suspensas) - (células contêm listas suspensas)
# 191 METAS ANO PRESENTE - RISCOS (Pavimentação) - Nº PROCESSO - (caso o processo já tenha sido protocolado) - (caso o processo já tenha sido protocolado)
# 192 METAS ANO PRESENTE - RISCOS (Pavimentação) - DATA DO PROTOCOLO - (Data do último documento encaminhado)(D/M/A) - (Data do último documento encaminhado)(D/M/A)
# 193 METAS ANO PRESENTE - RISCOS (Pavimentação) - LICENÇA - Foi solicitado licença para o segmento? - Foi solicitado licença para o segmento?
# 194 METAS ANO PRESENTE - RISCOS (Pavimentação) - LICENÇA - O pedido de licença desse segmento está dentro de um pedido de trecho maior? - O pedido de licença desse segmento está dentro de um pedido de trecho maior?
# 195 METAS ANO PRESENTE - RISCOS (Pavimentação) - LICENÇA - Se positivo, especificar o trecho completo requisitado - km(i) - km(f). - Se positivo, especificar o trecho completo requisitado - km(i) - km(f).
# 196 METAS ANO PRESENTE - RISCOS (Pavimentação) - SITUAÇÃO GERAL - (Colocar aqui observações gerais; Quando escolher a opção Outros, descrever a situação de forma suscinta.) - (Colocar aqui observações gerais; Quando escolher a opção Outros, descrever a situação de forma suscinta.)

# %%
for i, c in enumerate(colunas):

    if "PROCESSO" in c.upper():
        print(i, c)
# Out:
# 191 METAS ANO PRESENTE - RISCOS (Pavimentação) - Nº PROCESSO - (caso o processo já tenha sido protocolado) - (caso o processo já tenha sido protocolado)
# 211 METAS ANO PRESENTE - RISCOS (Duplicação) - Nº PROCESSO - (caso o processo já tenha sido protocolado) - (caso o processo já tenha sido protocolado)
# 231 METAS ANO PRESENTE - RISCOS (OAE) - Nº PROCESSO - (caso o processo já tenha sido protocolado) - (caso o processo já tenha sido protocolado)
# 251 METAS ANO PRESENTE - RISCOS (Contorno) - Nº PROCESSO - (caso o processo já tenha sido protocolado) - (caso o processo já tenha sido protocolado)
# 271 METAS ANO PRESENTE - RISCOS (FX Adicional) - Nº PROCESSO - (caso o processo já tenha sido protocolado) - (caso o processo já tenha sido protocolado)
# 291 METAS ANO PRESENTE - RISCOS (Terceira Faixa) - Nº PROCESSO - (caso o processo já tenha sido protocolado) - (caso o processo já tenha sido protocolado)

# %%
indice_colunas = pd.DataFrame({
    "indice": range(len(df.columns)),
    "coluna": df.columns
})

display(indice_colunas)
# Out:
#      indice                                             coluna
# 0         0          Região - Região - Região - Região - Norte
# 1         1         SETOR - SETOR - SETOR - SETOR - Rodoviário
# 2         2                     UF - UF - UF - UF - Rodoviário
# 3         3  ESTADO/LOTE - ESTADO/LOTE - Nº Concessões: - N...
# 4         4                        BR - BR - RIO GRANDE DO SUL
# ..      ...                                                ...
# 579     579  METAS ANO PRESENTE - OBSERVAÇÕES - SITUAÇÃO GE...
# 580     580  METAS ANO PRESENTE - OBSERVAÇÕES - SITUAÇÃO GE...
# 581     581  METAS ANO PRESENTE - OBSERVAÇÕES - SITUAÇÃO GE...
# 582     582  METAS ANO PRESENTE - OBSERVAÇÕES - SITUAÇÃO GE...
# 583     583  METAS ANO PRESENTE - OBSERVAÇÕES - SITUAÇÃO GE...
#
# [584 rows x 2 columns]

# %%
indice_colunas[
    indice_colunas["coluna"].str.contains(
        "PROCESSO",
        case=False,
        na=False
    )
]
# Out:
#      indice                                             coluna
# 191     191  METAS ANO PRESENTE - RISCOS (Pavimentação) - N...
# 211     211  METAS ANO PRESENTE - RISCOS (Duplicação) - Nº ...
# 231     231  METAS ANO PRESENTE - RISCOS (OAE) - Nº PROCESS...
# 251     251  METAS ANO PRESENTE - RISCOS (Contorno) - Nº PR...
# 271     271  METAS ANO PRESENTE - RISCOS (FX Adicional) - N...
# 291     291  METAS ANO PRESENTE - RISCOS (Terceira Faixa) -...

# %%
indice_colunas[
    indice_colunas["coluna"].str.contains(
        "LICEN",
        case=False,
        na=False
    )
]
# Out:
#      indice                                             coluna
# 193     193  METAS ANO PRESENTE - RISCOS (Pavimentação) - L...
# 194     194  METAS ANO PRESENTE - RISCOS (Pavimentação) - L...
# 195     195  METAS ANO PRESENTE - RISCOS (Pavimentação) - L...
# 213     213  METAS ANO PRESENTE - RISCOS (Duplicação) - LIC...
# 214     214  METAS ANO PRESENTE - RISCOS (Duplicação) - LIC...
# 215     215  METAS ANO PRESENTE - RISCOS (Duplicação) - LIC...
# 233     233  METAS ANO PRESENTE - RISCOS (OAE) - LICENÇA - ...
# 234     234  METAS ANO PRESENTE - RISCOS (OAE) - LICENÇA - ...
# 235     235  METAS ANO PRESENTE - RISCOS (OAE) - LICENÇA - ...
# 253     253  METAS ANO PRESENTE - RISCOS (Contorno) - LICEN...
# 254     254  METAS ANO PRESENTE - RISCOS (Contorno) - LICEN...
# 255     255  METAS ANO PRESENTE - RISCOS (Contorno) - LICEN...
# 273     273  METAS ANO PRESENTE - RISCOS (FX Adicional) - L...
# 274     274  METAS ANO PRESENTE - RISCOS (FX Adicional) - L...
# 275     275  METAS ANO PRESENTE - RISCOS (FX Adicional) - L...
# 293     293  METAS ANO PRESENTE - RISCOS (Terceira Faixa) -...
# 294     294  METAS ANO PRESENTE - RISCOS (Terceira Faixa) -...
# 295     295  METAS ANO PRESENTE - RISCOS (Terceira Faixa) -...

# %%
indice_colunas[
    indice_colunas["coluna"].str.contains(
        "FINANCEIRO PLAN",
        case=False,
        na=False
    )
]
# Out:
#      indice                                             coluna
# 183     183  METAS ANO PRESENTE - PAVIMENTAÇÃO             ...
# 203     203  METAS ANO PRESENTE - DUPLICAÇÃO               ...
# 223     223  METAS ANO PRESENTE - OAE                      ...
# 243     243  METAS ANO PRESENTE - CONTORNO                 ...
# 263     263  METAS ANO PRESENTE - FX ADICIONAL             ...
# 283     283  METAS ANO PRESENTE - TERCEIRA FAIXA           ...

# %%
df.columns = [
    str(c)
        .replace("\n", " ")
        .replace("\r", " ")
        .strip()
    for c in df.columns
]

# %%
print("Total de colunas:", len(df.columns))
print("Colunas únicas:", len(set(df.columns)))
# Out:
# Total de colunas: 584
# Colunas únicas: 584

# %%
import pandas as pd

cab = []

for c in range(1, ws.max_column + 1):

    info = {
        "coluna": c
    }

    for r in range(1, 9):

        info[f"L{r}"] = ws.cell(r, c).value

    cab.append(info)

cab = pd.DataFrame(cab)

cab.head()
# Out:
#    coluna                                    L1   L2           L3    L4  \
# 0       1                                   NaN  NaN       Região  None
# 1       2                                   NaN  NaN        SETOR  None
# 2       3                                   NaN                UF  None
# 3       4             PLANILHA DE MONITORAMENTO  NaN  ESTADO/LOTE  None
# 4       5                                   NaN  NaN           BR  None
#
#                                                   L5   L6                 L7  \
# 0                                                NaN  NaN              Norte
# 1                                                NaN  NaN         Rodoviário
# 2                                                NaN  NaN                NaN
# 3                                     Nº Concessões:  NaN  RIO GRANDE DO SUL
# 4  =E7+E20+E30+E38+E58+E71+E82+E98+E101+E104+E106...  NaN                NaN
#
#                   L8
# 0              Norte
# 1         Rodoviário
# 2                 RS
# 3  RIO GRANDE DO SUL
# 4                101

# %%
def limpar(x):

    if x is None:
        return ""

    x = str(x).strip()

    if x.startswith("="):
        return ""

    if x == "#REF!":
        return ""

    return x

for c in cab.columns[1:]:

    cab[c] = cab[c].apply(limpar)

# %%
pd.set_option("display.max_colwidth", None)

cab.iloc[175:205]
# Out:
#      coluna                                       L1                  L2  \
# 175     176  PER - PROGRAMA DE EXPLORAÇÃO DA RODOVIA                 nan
# 176     177  PER - PROGRAMA DE EXPLORAÇÃO DA RODOVIA                 nan
# 177     178                            META ANO 2026  METAS ANO PRESENTE
# 178     179                            META ANO 2026  METAS ANO PRESENTE
# 179     180                            META ANO 2026  METAS ANO PRESENTE
# 180     181                            META ANO 2026  METAS ANO PRESENTE
# 181     182                            META ANO 2026  METAS ANO PRESENTE
# 182     183                            META ANO 2026  METAS ANO PRESENTE
# 183     184                            META ANO 2026  METAS ANO PRESENTE
# 184     185                            META ANO 2026  METAS ANO PRESENTE
# 185     186                            META ANO 2026  METAS ANO PRESENTE
# 186     187                            META ANO 2026  METAS ANO PRESENTE
# 187     188                            META ANO 2026  METAS ANO PRESENTE
# 188     189                            META ANO 2026  METAS ANO PRESENTE
# 189     190                            META ANO 2026  METAS ANO PRESENTE
# 190     191                            META ANO 2026  METAS ANO PRESENTE
# 191     192                            META ANO 2026  METAS ANO PRESENTE
# 192     193                            META ANO 2026  METAS ANO PRESENTE
# 193     194                            META ANO 2026  METAS ANO PRESENTE
# 194     195                            META ANO 2026  METAS ANO PRESENTE
# 195     196                            META ANO 2026  METAS ANO PRESENTE
# 196     197                            META ANO 2026  METAS ANO PRESENTE
# 197     198                            META ANO 2026  METAS ANO PRESENTE
# 198     199                            META ANO 2026  METAS ANO PRESENTE
# 199     200                            META ANO 2026  METAS ANO PRESENTE
# 200     201                            META ANO 2026  METAS ANO PRESENTE
# 201     202                            META ANO 2026  METAS ANO PRESENTE
# 202     203                            META ANO 2026  METAS ANO PRESENTE
# 203     204                            META ANO 2026  METAS ANO PRESENTE
# 204     205                            META ANO 2026  METAS ANO PRESENTE
#
#                                                                                                                                                                                                                                                                                                                          L3  \
# 175                                                                                                                                                                                                                                                                                                          TERCEIRA FAIXA
# 176                                                                                                                                                                                                                                                                                                          TERCEIRA FAIXA
# 177          PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente)
# 178          PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente)
# 179          PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente)
# 180          PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente)
# 181          PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente)
# 182          PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente)
# 183          PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente)
# 184          PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente)
# 185          PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente)
# 186          PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente)
# 187                                                                                                                                                                                                                                                                                                   RISCOS (Pavimentação)
# 188                                                                                                                                                                                                                                                                                                   RISCOS (Pavimentação)
# 189                                                                                                                                                                                                                                                                                                   RISCOS (Pavimentação)
# 190                                                                                                                                                                                                                                                                                                   RISCOS (Pavimentação)
# 191                                                                                                                                                                                                                                                                                                                     nan
# 192                                                                                                                                                                                                                                                                                                                     nan
# 193                                                                                                                                                                                                                                                                                                                     nan
# 194                                                                                                                                                                                                                                                                                                                     nan
# 195                                                                                                                                                                                                                                                                                                                     nan
# 196                                                                                                                                                                                                                                                                                                                     nan
# 197  DUPLICAÇÃO                                                                                                                                                                                                                                                                                               (Ano Vigente)
# 198  DUPLICAÇÃO                                                                                                                                                                                                                                                                                               (Ano Vigente)
# 199  DUPLICAÇÃO                                                                                                                                                                                                                                                                                               (Ano Vigente)
# 200  DUPLICAÇÃO                                                                                                                                                                                                                                                                                               (Ano Vigente)
# 201  DUPLICAÇÃO                                                                                                                                                                                                                                                                                               (Ano Vigente)
# 202  DUPLICAÇÃO                                                                                                                                                                                                                                                                                               (Ano Vigente)
# 203  DUPLICAÇÃO                                                                                                                                                                                                                                                                                               (Ano Vigente)
# 204  DUPLICAÇÃO                                                                                                                                                                                                                                                                                               (Ano Vigente)
#
#                        L4  \
# 175              PÓS 2026
# 176              PÓS 2026
# 177           FÍSICO (km)
# 178           FÍSICO (km)
# 179           FÍSICO (km)
# 180           FÍSICO (km)
# 181   PERCENTUAL (%) PLAN
# 182            (km)% PLAN
# 183  FINANCEIRO PLAN (R$)
# 184   PERCENTUAL (%) EXEC
# 185            (km)% EXEC
# 186       FINANCEIRO (R$)
# 187              SITUAÇÃO
# 188         INTERFERÊNCIA
# 189             PRINCIPAL
# 190       NÍVEL DE ALERTA
# 191           Nº PROCESSO
# 192     DATA DO PROTOCOLO
# 193               LICENÇA
# 194               LICENÇA
# 195               LICENÇA
# 196        SITUAÇÃO GERAL
# 197           FÍSICO (km)
# 198           FÍSICO (km)
# 199           FÍSICO (km)
# 200           FÍSICO (km)
# 201   PERCENTUAL (%) PLAN
# 202            (km)% PLAN
# 203  FINANCEIRO PLAN (R$)
# 204   PERCENTUAL (%) EXEC
#
#                                                                                                              L5  \
# 175                                                                                              PERCENTUAL (%)
# 176                                                                                             FINANCEIRO (R$)
# 177                                                                                                   Descrição
# 178                                                                                                      km (i)
# 179                                                                                                      km (f)
# 180                                                                                                   Ext. (km)
# 181                                                                                             PAV. TOTAL PLAN
# 182
# 183
# 184                                                                                             PAV. TOTAL EXEC
# 185
# 186
# 187                                                                           (células contêm listas suspensas)
# 188                                                                           (células contêm listas suspensas)
# 189                                                                           (células contêm listas suspensas)
# 190                                                                           (células contêm listas suspensas)
# 191                                                                 (caso o processo já tenha sido protocolado)
# 192                                                               (Data do último documento encaminhado)(D/M/A)
# 193                                                                     Foi solicitado licença para o segmento?
# 194                                O pedido de licença desse segmento está dentro de um pedido de trecho maior?
# 195                                     Se positivo, especificar o trecho completo requisitado - km(i) - km(f).
# 196  (Colocar aqui observações gerais; Quando escolher a opção Outros, descrever a situação de forma suscinta.)
# 197                                                                                                   Descrição
# 198                                                                                                      km (i)
# 199                                                                                                      km (f)
# 200                                                                                                   Ext. (km)
# 201                                                                                          DUPLIC. TOTAL PLAN
# 202
# 203
# 204                                                                                          DUPLIC. TOTAL EXEC
#
#                                                                                                              L6  \
# 175                                                                                                         nan
# 176                                                                                                         nan
# 177                                                                                                         nan
# 178                                                                                                         nan
# 179                                                                                                         nan
# 180                                                                                                         nan
# 181                                                                                                         nan
# 182                                                                                                         nan
# 183                                                                                                         nan
# 184                                                                                                         nan
# 185                                                                                                         nan
# 186                                                                                                         nan
# 187                                                                           (células contêm listas suspensas)
# 188                                                                           (células contêm listas suspensas)
# 189                                                                           (células contêm listas suspensas)
# 190                                                                           (células contêm listas suspensas)
# 191                                                                 (caso o processo já tenha sido protocolado)
# 192                                                               (Data do último documento encaminhado)(D/M/A)
# 193                                                                     Foi solicitado licença para o segmento?
# 194                                O pedido de licença desse segmento está dentro de um pedido de trecho maior?
# 195                                     Se positivo, especificar o trecho completo requisitado - km(i) - km(f).
# 196  (Colocar aqui observações gerais; Quando escolher a opção Outros, descrever a situação de forma suscinta.)
# 197                                                                                                         nan
# 198                                                                                                         nan
# 199                                                                                                         nan
# 200                                                                                                         nan
# 201                                                                                                         nan
# 202                                                                                                         nan
# 203                                                                                                         nan
# 204                                                                                                         nan
#
#         L7    L8
# 175    nan
# 176    nan
# 177    nan
# 178    nan
# 179    nan
# 180    nan
# 181  TOTAL  SOMA
# 182
# 183
# 184  TOTAL  SOMA
# 185
# 186
# 187    nan
# 188    nan
# 189    nan
# 190    nan
# 191    nan
# 192    nan
# 193    nan
# 194    nan
# 195    nan
# 196    nan
# 197    nan
# 198    nan
# 199    nan
# 200    nan
# 201  TOTAL  SOMA
# 202
# 203
# 204  TOTAL  SOMA

# %%
# %% =====================================================================
# CRIAÇÃO DO DATAFRAME FINAL COM AS 43 COLUNAS ESPECIFICADAS
# ========================================================================

# Lista atualizada com as novas colunas
colunas_alvo = [
    "ID-ÚNICO",
    "SETOR",
    "UF",
    "BR",
    "EMPREENDIMENTO",
    "EXECUTOR (Grupo Controlador)",
    "DATA DE INÍCIO DA CONCESSÃO",
    "ANO DA CONCESSÃO",
    "INTERFERÊNCIAS",
    "INTERVENÇÃO AFETADA",
    "Descrição",
    "km(i)",
    "km(f)",
    "Ext.(km)",
    "Ext.(km)!",
    "FINANCEIRO(R$)",
    "FINANCEIRO(R$)!",
    "PER ANO(Execução)",
    "LP",
    "LI",
    "LO",
    "DATA DE INÍCIO",
    "SINAFLOR",
    "SISGLAF",
    "SEI",
    "Risco Principal",
    "CRITICIDADE",
    "SITUAÇÃO",
    "COMENTÁRIOS GERAIS",
    "Data do Atendimento",
    "NÍVEL DE ALERTA",
    "Emitida",
    "Em análise",
    "Aguardando",
    "Solicitada",
    "Sem informação",
    "Pendência",
    "Outras Descrições",
    # ===== NOVAS COLUNAS ADICIONADAS =====
    "Nº PROCESSO",
    "DATA DO PROTOCOLO",
    "LICENÇA",
    "SITUAÇÃO GERAL",
    # ====================================
    "PLANILHA"
]

# Cria o DataFrame final vazio, com o mesmo índice do df original
df_final = pd.DataFrame(index=df.index, columns=colunas_alvo)

# ========================================================================
# 1. DEFINIÇÃO DOS MAPEAMENTOS (palavras-chave para cada coluna destino)
# ========================================================================

mapeamento = {
    "ID-ÚNICO": ["ID", "UNICO"],
    "SETOR": ["SETOR"],
    "UF": ["UF"],
    "BR": ["BR"],
    "EMPREENDIMENTO": ["EMPREENDIMENTO"],
    "EXECUTOR (Grupo Controlador)": ["EXECUTOR", "CONTROLADOR"],
    "DATA DE INÍCIO DA CONCESSÃO": ["CONCESSÃO", "INÍCIO"],
    "ANO DA CONCESSÃO": ["ANO", "CONCESSÃO"],
    "INTERFERÊNCIAS": ["INTERFER"],
    "INTERVENÇÃO AFETADA": ["INTERVENÇÃO", "AFETADA"],
    "Descrição": ["DESCRIÇÃO"],
    "km(i)": ["KM I", "KM INICIAL"],
    "km(f)": ["KM F", "KM FINAL"],
    "Ext.(km)": ["EXT", "KM"],  # pega a primeira com EXT e KM
    "Ext.(km)!": ["EXT", "!", "KM"],  # pega a que tem "!"
    "FINANCEIRO(R$)": ["FINANCEIRO", "R$"],
    "FINANCEIRO(R$)!": ["FINANCEIRO", "R$", "!"],
    "PER ANO(Execução)": ["PER ANO", "EXECUÇÃO"],
    "LP": ["LP"],
    "LI": ["LI"],
    "LO": ["LO"],
    "DATA DE INÍCIO": ["DATA DE INÍCIO"],  # será tratado com exclusão de "CONCESSÃO"
    "SINAFLOR": ["SINAFLOR"],
    "SISGLAF": ["SISGLAF"],
    "SEI": ["SEI"],
    "Risco Principal": ["RISCO", "PRINCIPAL"],
    "CRITICIDADE": ["CRITICIDADE"],
    "SITUAÇÃO": ["SITUAÇÃO"],  # sem a palavra GERAL para não confundir
    "COMENTÁRIOS GERAIS": ["COMENTÁRIOS", "GERAIS"],
    "Data do Atendimento": ["ATENDIMENTO"],
    "NÍVEL DE ALERTA": ["ALERTA"],
    "Emitida": ["EMITIDA"],
    "Em análise": ["ANÁLISE"],
    "Aguardando": ["AGUARDANDO"],
    "Solicitada": ["SOLICITADA"],
    "Sem informação": ["SEM INFORMAÇÃO"],
    "Pendência": ["PENDÊNCIA"],
    "Outras Descrições": ["OUTRAS", "DESCRI"],
    # ===== MAPEAMENTO DAS NOVAS COLUNAS =====
    "Nº PROCESSO": ["PROCESSO", "Nº"],  # ou "NÚMERO" se preferir
    "DATA DO PROTOCOLO": ["PROTOCOLO", "DATA"],
    "LICENÇA": ["LICENÇA"],
    "SITUAÇÃO GERAL": ["SITUAÇÃO", "GERAL"],  # distinta de "SITUAÇÃO" sozinha
    # ========================================
    "PLANILHA": []  # será preenchida manualmente
}

# ========================================================================
# 2. FUNÇÃO PARA ENCONTRAR A COLUNA DE ORIGEM
# ========================================================================

def encontrar_coluna_origem(palavras, ignorar=None):
    """
    Retorna o nome da coluna em df.columns que contém TODAS as palavras da lista.
    Se 'ignorar' for passado, ignora colunas que contenham essa palavra.
    """
    for col in df.columns:
        col_str = str(col).upper()
        # Se tiver palavra para ignorar, pula
        if ignorar and ignorar.upper() in col_str:
            continue
        # Verifica se todas as palavras estão presentes
        if all(p.upper() in col_str for p in palavras):
            return col
    return None

# ========================================================================
# 3. PREENCHIMENTO COLUNA POR COLUNA
# ========================================================================

print("🔍 Mapeamento realizado:\n")

for destino, palavras in mapeamento.items():
    
    # Caso especial: PLANILHA
    if destino == "PLANILHA":
        df_final[destino] = "META (2027)"
        print(f"  {destino:30} <- (preenchido com 'META (2027)')")
        continue
    
    # Caso especial: "DATA DE INÍCIO" (da intervenção) deve ignorar "CONCESSÃO"
    if destino == "DATA DE INÍCIO":
        origem = encontrar_coluna_origem(palavras, ignorar="CONCESSÃO")
    else:
        origem = encontrar_coluna_origem(palavras)
    
    if origem:
        df_final[destino] = df[origem]
        print(f"  {destino:30} <- {origem}")
    else:
        print(f"  {destino:30} <- ⚠️ NÃO ENCONTRADO (deixado como NaN)")

# ========================================================================
# 4. (OPCIONAL) AJUSTES FINOS MANUAIS
# ========================================================================
# Se alguma coluna foi mapeada errada, você pode sobrescrever aqui.
# Exemplo:
# col_correta = encontrar_coluna_origem(["PROCESSO"], ignorar="Nº")  # ajuste conforme necessário
# if col_correta:
#     df_final["Nº PROCESSO"] = df[col_correta]

# ========================================================================
# 5. EXIBE E SALVA
# ========================================================================

print("\n📊 Primeiras linhas do DataFrame final:")
print(df_final.head())

print(f"\nFormato final: {df_final.shape[0]} linhas x {df_final.shape[1]} colunas")

# Salva em Excel
arquivo_final = "PPI_Colunas_Especificas - 2027.xlsx"
with pd.ExcelWriter(arquivo_final, engine="openpyxl") as writer:
    df_final.to_excel(writer, index=False, sheet_name="META_2027")

print(f"\n✅ Arquivo exportado: {arquivo_final}")
# Out:
# 🔍 Mapeamento realizado:
#
#   ID-ÚNICO                       <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   SETOR                          <- SETOR - SETOR - SETOR - SETOR - Rodoviário
#   UF                             <- UF - UF - UF - UF - Rodoviário
#   BR                             <- BR - BR - RIO GRANDE DO SUL
#   EMPREENDIMENTO                 <- DADOS CONTRATUAIS - EMPREENDIMENTO - EMPREENDIMENTO - CONCESSÃO VIA SUL
#   EXECUTOR (Grupo Controlador)   <- DADOS CONTRATUAIS - EXECUTOR             (Grupo Controlador) - EXECUTOR             (Grupo Controlador) - MOTIVA
#   DATA DE INÍCIO DA CONCESSÃO    <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   ANO DA CONCESSÃO               <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   INTERFERÊNCIAS                 <- METAS ANO PRESENTE - RISCOS (Pavimentação) - INTERFERÊNCIA - (células contêm listas suspensas) - (células contêm listas suspensas)
#   INTERVENÇÃO AFETADA            <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Descrição                      <- METAS ANO PRESENTE - PAVIMENTAÇÃO                                                                                                                                                                                                                                                                                     (Ano Vigente) - FÍSICO (km) - Descrição - Ext. (km) - EPL
#   km(i)                          <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   km(f)                          <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Ext.(km)                       <- DADOS CONTRATUAIS - PAVIMENTAÇÃO - Até 2022 - FÍSICO (km) - Ext. (km) - EPL
#   Ext.(km)!                      <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   FINANCEIRO(R$)                 <- DADOS CONTRATUAIS - PAVIMENTAÇÃO - Até 2022 - FINANCEIRO (R$) - Ext. (km) - EPL
#   FINANCEIRO(R$)!                <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   PER ANO(Execução)              <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   LP                             <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   LI                             <- DADOS CONTRATUAIS - DUPLICAÇÃO - Até 2022 - FÍSICO (km) - km (i) - EPL
#   LO                             <- ESTADO/LOTE - ESTADO/LOTE - Nº Concessões: - Nº Concessões: - RIO GRANDE DO SUL
#   DATA DE INÍCIO                 <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   SINAFLOR                       <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   SISGLAF                        <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   SEI                            <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Risco Principal                <- METAS ANO PRESENTE - RISCOS (Pavimentação) - PRINCIPAL - (células contêm listas suspensas) - (células contêm listas suspensas)
#   CRITICIDADE                    <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   SITUAÇÃO                       <- METAS ANO PRESENTE - RISCOS (Pavimentação) - SITUAÇÃO - (células contêm listas suspensas) - (células contêm listas suspensas)
#   COMENTÁRIOS GERAIS             <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Data do Atendimento            <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   NÍVEL DE ALERTA                <- METAS ANO PRESENTE - RISCOS (Pavimentação) - NÍVEL DE ALERTA - (células contêm listas suspensas) - (células contêm listas suspensas)
#   Emitida                        <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Em análise                     <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Aguardando                     <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Solicitada                     <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Sem informação                 <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Pendência                      <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Outras Descrições              <- ⚠️ NÃO ENCONTRADO (deixado como NaN)
#   Nº PROCESSO                    <- METAS ANO PRESENTE - RISCOS (Pavimentação) - Nº PROCESSO - (caso o processo já tenha sido protocolado) - (caso o processo já tenha sido protocolado)
#   DATA DO PROTOCOLO              <- METAS ANO PRESENTE - RISCOS (Pavimentação) - DATA DO PROTOCOLO - (Data do último documento encaminhado)(D/M/A) - (Data do último documento encaminhado)(D/M/A)
#   LICENÇA                        <- METAS ANO PRESENTE - RISCOS (Pavimentação) - LICENÇA - Foi solicitado licença para o segmento? - Foi solicitado licença para o segmento?
#   SITUAÇÃO GERAL                 <- METAS ANO PRESENTE - RISCOS (Pavimentação) - SITUAÇÃO GERAL - (Colocar aqui observações gerais; Quando escolher a opção Outros, descrever a situação de forma suscinta.) - (Colocar aqui observações gerais; Quando escolher a opção Outros, descrever a situação de forma suscinta.)
#   PLANILHA                       <- (preenchido com 'META (2027)')
#
# 📊 Primeiras linhas do DataFrame final:
#   ID-ÚNICO       SETOR  UF   BR     EMPREENDIMENTO  \
# 0      NaN  Rodoviário  RS  101  CONCESSÃO VIA SUL
# 1      NaN  Rodoviário  RS  101  CONCESSÃO VIA SUL
# 2      NaN  Rodoviário  RS  101  CONCESSÃO VIA SUL
# 3      NaN  Rodoviário  RS  290  CONCESSÃO VIA SUL
# 4      NaN  Rodoviário  RS  290  CONCESSÃO VIA SUL
#
#   EXECUTOR (Grupo Controlador) DATA DE INÍCIO DA CONCESSÃO ANO DA CONCESSÃO  \
# 0                       MOTIVA                         NaN              NaN
# 1                       MOTIVA                         NaN              NaN
# 2                       MOTIVA                         NaN              NaN
# 3                       MOTIVA                         NaN              NaN
# 4                       MOTIVA                         NaN              NaN
#
#   INTERFERÊNCIAS INTERVENÇÃO AFETADA  ... Aguardando Solicitada  \
# 0            NaN                 NaN  ...        NaN        NaN
# 1            NaN                 NaN  ...        NaN        NaN
# 2            NaN                 NaN  ...        NaN        NaN
# 3            NaN                 NaN  ...        NaN        NaN
# 4            NaN                 NaN  ...        NaN        NaN
#
#   Sem informação Pendência Outras Descrições Nº PROCESSO DATA DO PROTOCOLO  \
# 0            NaN       NaN               NaN         NaN               NaT
# 1            NaN       NaN               NaN         NaN               NaT
# 2            NaN       NaN               NaN         NaN               NaT
# 3            NaN       NaN               NaN         NaN               NaT
# 4            NaN       NaN               NaN         NaN               NaT
#
#   LICENÇA SITUAÇÃO GERAL     PLANILHA
# 0     NaN            NaN  META (2027)
# 1     NaN            NaN  META (2027)
# 2     NaN            NaN  META (2027)
# 3     NaN            NaN  META (2027)
# 4     NaN            NaN  META (2027)
#
# [5 rows x 43 columns]
#
# Formato final: 370 linhas x 43 colunas
#
# ✅ Arquivo exportado: PPI_Colunas_Especificas - 2027.xlsx

# %%
arquivo_saida = "PPI_Tratada - 2027.xlsx"

with pd.ExcelWriter(
    arquivo_saida,
    engine="openpyxl"
) as writer:

    df.to_excel(
        writer,
        index=False,
        sheet_name="META(2027)"
    )

print("Exportação concluída.")
# Out:
# Exportação concluída.
